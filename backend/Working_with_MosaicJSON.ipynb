# %% [markdown]
# # Working With MosaicJSON
#
# [![Binder](https://mybinder.org/badge_logo.svg)](https://mybinder.org/v2/gh/developmentseed/titiler/main?filepath=docs%2Fexamples%2F%2Fnotebooks%2FWorking_with_MosaicJSON.ipynb)
#
# ### MosaicJSON
#
# MosaicJSON is a specification created by DevelopmentSeed which aims to be an open standard for representing metadata about a mosaic of Cloud-Optimized GeoTIFF (COG) files.
#
#
# > MosaicJSON can be seen as a Virtual raster (see GDAL's VRT) enabling spatial and temporal processing for a list of Cloud-Optimized GeoTIFF.
#
# Ref:https://github.com/developmentseed/mosaicjson-spec
#
#
# ### Data
#
# For this demo, we are going to use CloudOptimized GeoTIFF from NOAA/Emergency Response Imagery: https://registry.opendata.aws/noaa-eri/
#
# Requirement: AWS credentials
#
#
# ### Endpoint
#
# By default, TiTiler has `mosaicjson` endpoints.
#
# Docs: https://titiler.xyz/api.html#/MosaicJSON

# %% [markdown]
# ## Requirements
#
# To be able to run this notebook you'll need the following requirements:
# - rasterio
# - folium
# - httpx
# - tqdm
# - rio-tiler
# - cogeo-mosaic
# - boto3
# - geojson_pydantic
#
# `pip install rasterio folium tqdm httpx rio-tiler geojson_pydantic cogeo-mosaic`

# %%
# Uncomment this line if you need to install the dependencies
#!pip install rasterio folium tqdm httpx rio-tiler geojson_pydantic cogeo-mosaic

# %% [markdown]
# ## Get the Data

# %%
import os
import json
import rasterio
import httpx
from boto3.session import Session as boto3_session

from concurrent import futures
from rio_tiler.io import COGReader
from rasterio.features import bounds as featureBounds

from folium import Map, TileLayer, GeoJson

# %% [markdown]
# ### 1. Fetch and parse page

# %%
# To Be able to run this notebook you'll need to have AWS credential available in the environment

# import os
# os.environ["AWS_ACCESS_KEY_ID"] = "YOUR AWS ACCESS ID HERE"
# os.environ["AWS_SECRET_ACCESS_KEY"] = "YOUR AWS ACCESS KEY HERE"

# %%
session = boto3_session(region_name="us-east-1")
client = session.client("s3")

bucket = "nz-imagery"  # https://registry.opendata.aws/omi-no2-nasa/


def list_objects(bucket, prefix):
    """AWS s3 list objects."""

    paginator = client.get_paginator("list_objects_v2")

    files = []
    for subset in paginator.paginate(Bucket=bucket, Prefix=prefix):
        files.extend(subset.get("Contents", []))
        print("\r"+str(files[-1]))

    return [r["Key"] for r in files]


files = list_objects(bucket, "")
files = [f"s3://{bucket}/{f}" for f in files if f.endswith(".tif")]

print(f"Number of GeoTIFF: {len(files)}")
# Out:
# {'Key': 'auckland/auckland-coast_2022-2023_0.05m/rgb/2193/AY34_1000_3128.json', 'LastModified': datetime.datetime(2024, 11, 28, 21, 36, 13, tzinfo=tzutc()), 'ETag': '"229a8b47fa2259c80db3d98b35aa57b1"', 'Size': 1163, 'StorageClass': 'STANDARD'}
# {'Key': 'auckland/auckland-coast_2022-2023_0.05m/rgb/2193/AZ30_1000_1120.json', 'LastModified': datetime.datetime(2024, 11, 28, 21, 36, 13, tzinfo=tzutc()), 'ETag': '"665df6793639358b8e5db917f68c86ad"', 'Size': 1162, 'StorageClass': 'STANDARD'}
# {'Key': 'auckland/auckland-coast_2022-2023_0.05m/rgb/2193/AZ30_1000_4826.json', 'LastModified': datetime.datetime(2024, 11, 28, 21, 36, 12, tzinfo=tzutc()), 'ETag': '"adb51de8b23ab3b38b037c2d6fd1d479"', 'Size': 1160, 'StorageClass': 'STANDARD'}
# {'Key': 'auckland/auckland-coast_2022-2023_0.05m/rgb/2193/AZ32_1000_2803.json', 'LastModified': datetime.datetime(2024, 11, 28, 21, 36, 12, tzinfo=tzutc()), 'ETag': '"648ee924b8f817e7f1dd26944c06805d"', 'Size': 1162, 'StorageClass': 'STANDARD'}
# {'Key': 'auckland/auckland-coast_2022-2023_0.05m/rgb/2193/BA31_1000_2730.json', 'LastModified': datetime.datetime(2024, 11, 28, 21, 36, 12, tzinfo=tzutc()), 'ETag': '"808cbae53dcf93a5b656a29951fc59e4"', 'Size': 1159, 'StorageClass': 'STANDARD'}
# {'Key': 'auckland/auckland-coast_2022-2023_0.05m/rgb/2193/BA32_1000_3601.json', 'LastModified': datetime.datetime(2024, 11, 28, 21, 36, 12, tzinfo=tzutc()), 'ETag': '"5ab457107dd03b64da1710d1a305df3a"', 'Size': 1159, 'StorageClass': 'STANDARD'}
# {'Key': 'auckland/auckland-coast_2022-2023_0.05m/rgb/2193/BA33_1000_4206.json', 'LastModified': datetime.datetime(2024, 11, 28, 21, 36, 13, tzinfo=tzutc()), 'ETag': '"a22944619bbd107a0f7f1b2e9d8454f0"', 'Size': 1161, 'StorageClass': 'STANDARD'}
# {'Key': 'auckland/auckland-coast_2022-2023_0.05m/rgb/2193/BB31_1000_3139.json', 'LastModified': datetime.datetime(2024, 11, 28, 21, 36, 13, tzinfo=tzutc()), 'ETag': '"711ded0dfe8d36b860b5e0bc2255ee9d"', 'Size': 1161, 'StorageClass': 'STANDARD'}
# {'Key': 'auckland/auckland-coast_2022-2023_0.05m/rgb/2193/BB32_1000_2504.json', 'LastModified': datetime.datetime(2024, 11, 28, 21, 36, 13, tzinfo=tzutc()), 'ETag': '
 'StorageClass': 'STANDARD'}
# {'Key': 'bay-of-plenty/bay-of-plenty_2023_0.1m/rgb/2193/BD37_1000_3123.json', 'LastModified': datetime.datetime(2024, 11, 28, 21, 39, 21, tzinfo=tzutc()), 'ETag': '"dae7527ab98b42c8cccb20d45a8a75d7"', 'Size': 1163, 'StorageClass': 'STANDARD'}
# {'Key': 'bay-of-plenty/bay-of-plenty_2023_0.1m/rgb/2193/BE37_1000_2735.json', 'LastModified': datetime.datetime(2024, 11, 28, 21, 39, 21, tzinfo=tzutc()), 'ETag': '"543803455d2d9a7197987e43d66158ef"', 'Size': 1159, 'StorageClass': 'STANDARD'}
# {'Key': 'bay-of-plenty/bay-of-plenty_2023_0.1m/rgb/2193/BE38_1000_2713.json', 'LastModified': datetime.datetime(2024, 11, 28, 21, 39, 23, tzinfo=tzutc()), 'ETag': '"6def709ac0c7a1e6f0ae5dd983a08267"', 'Size': 1158, 'StorageClass': 'STANDARD'}
# {'Key': 'bay-of-plenty/bay-of-plenty_2023_0.1m/rgb/2193/BF37_1000_3634.json', 'LastModified': datetime.datetime(2024, 11, 28, 21, 39, 23, tzinfo=tzutc()), 'ETag': '"217cd446feac44379085f681d3399296"', 'Size': 1162, 'StorageClass': 'STANDARD'}
# {'Key': 'bay-of-plenty/bay-of-plenty_2024_0.2m/rgb/2193/BD36_2000_0804.tiff', 'LastModified': datetime.datetime(2024, 9, 11, 3, 40, 50, tzinfo=tzutc()), 'ETag': '"785d6e73826789baafb3251007b15d6f-4"', 'Size': 47146526, 'StorageClass': 'INTELLIGENT_TIERING'}
# {'Key': 'bay-of-plenty/bay-of-plenty_2024_0.2m/rgb/2193/BD37_2000_1212.tiff', 'LastModified': datetime.datetime(2025, 3, 19, 0, 43, 56, tzinfo=tzutc()), 'ETag': '"30abb3037b00a4433d8b65737b9a9cc2-4"', 'ChecksumAlgorithm': ['CRC64NVME'], 'ChecksumType': 'FULL_OBJECT', 'Size': 40868640, 'StorageClass': 'INTELLIGENT_TIERING'}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 20
#      15         print("\r"+str(files[-1]))
#      17     return [r["Key"] for r in files]
# ---> 20 files = list_objects(bucket, "")
#      21 files = [f"s3://{bucket}/{f}" for f in files if f.endswith(".tif")]
#      23 print(f"Number of GeoTIFF: {len(files)}")
#
# Cell In[5], line 13, in list_objects(bucket, prefix)
#      10 paginator = client.get_paginator("list_objects_v2")
#      12 files = []
# ---> 13 for subset in paginator.paginate(Bucket=bucket, Prefix=prefix):
#      14     files.extend(subset.get("Contents", []))
#      15     print("\r"+str(files[-1]))
#
# File c:\Users\JaydenL\Documents\Uni\COMPX527\KiwiGuesser\.venv\Lib\site-packages\botocore\paginate.py:272, in PageIterator.__iter__(self)
#     270 self._inject_starting_params(current_kwargs)
#     271 while True:
# --> 272     response = self._make_request(current_kwargs)
#     273     parsed = self._extract_parsed_response(response)
#     274     if first_request:
#     275         # The first request is handled differently.  We could
#     276         # possibly have a resume/starting token that tells us where
#     277         # to index into the retrieved page.
#
# File c:\Users\JaydenL\Documents\Uni\COMPX527\KiwiGuesser\.venv\Lib\site-packages\botocore\context.py:123, in with_current_context.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     121 if hook:
#     122     hook()
# --> 123 return func(*args, **kwargs)
#
# File c:\Users\JaydenL\Documents\Uni\COMPX527\KiwiGuesser\.venv\Lib\site-packages\botocore\paginate.py:360, in PageIterator._make_request(self, current_kwargs)
#     358 @with_current_context(partial(register_feature_id, 'PAGINATOR'))
#     359 def _make_request(self, current_kwargs):
# --> 360     return self._method(**current_kwargs)
#
# File c:\Users\JaydenL\Documents\Uni\COMPX527\KiwiGuesser\.venv\Lib\site-packages\botocore\client.py:601, in ClientCreator._create_api_method.<locals>._api_call(self, *args, **kwargs)
#     597     raise TypeError(
#     598         f"{py_operation_name}() only accepts keyword arguments."
#     599     )
#     600 # The "self" in this scope is referring to the BaseClient.
# --> 601 return self._make_api_call(operation_name, kwargs)
#
# File c:\Users\JaydenL\Documents\Uni\COMPX527\KiwiGuesser\.venv\Lib\site-packages\botocore\context.py:123, in with_current_context.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     121 if hook:
#     122     hook()
# --> 123 return func(*args, **kwargs)
#
# File c:\Users\JaydenL\Documents\Uni\COMPX527\KiwiGuesser\.venv\Lib\site-packages\botocore\client.py:1056, in BaseClient._make_api_call(self, operation_name, api_params)
#    1052     maybe_compress_request(
#    1053         self.meta.config, request_dict, operation_model
#    1054     )
#    1055     apply_request_checksum(request_dict)
# -> 1056     http, parsed_response = self._make_request(
#    1057         operation_model, request_dict, request_context
#    1058     )
#    1060 self.meta.events.emit(
#    1061     f'after-call.{service_id}.{operation_name}',
#    1062     http_response=http,
#    (...)   1065     context=request_context,
#    1066 )
#    1068 if http.status_code >= 300:
#
# File c:\Users\JaydenL\Documents\Uni\COMPX527\KiwiGuesser\.venv\Lib\site-packages\botocore\client.py:1080, in BaseClient._make_request(self, operation_model, request_dict, request_context)
#    1078 def _make_request(self, operation_model, request_dict, request_context):
#    1079     try:
# -> 1080         return self._endpoint.make_request(operation_model, request_dict)
#    1081     except Exception as e:
#    1082         self.meta.events.emit(
#    1083             f'after-call-error.{self._service_model.service_id.hyphenize()}.{operation_model.name}',
#    1084             exception=e,
#    1085             context=request_context,
#    1086         )
#
# File c:\Users\JaydenL\Documents\Uni\COMPX527\KiwiGuesser\.venv\Lib\site-packages\botocore\endpoint.py:118, in Endpoint.make_request(self, operation_model, request_dict)
#     112 def make_request(self, operation_model, request_dict):
#     113     logger.debug(
#     114         "Making request for %s with params: %s",
#     115         operation_model,
#     116         request_dict,
#     117     )
# --> 118     return self._send_request(request_dict, operation_model)
#
# File c:\Users\JaydenL\Documents\Uni\COMPX527\KiwiGuesser\.venv\Lib\site-packages\botocore\endpoint.py:196, in Endpoint._send_request(self, request_dict, operation_model)
#     194 self._update_retries_context(context, attempts)
#     195 request = self.create_request(request_dict, operation_model)
# --> 196 success_response, exception = self._get_response(
#     197     request, operation_model, context
#     198 )
#     199 while self._needs_retry(
#     200     attempts,
#     201     operation_model,
#    (...)    204     exception,
#     205 ):
#     206     attempts += 1
#
# File c:\Users\JaydenL\Documents\Uni\COMPX527\KiwiGuesser\.venv\Lib\site-packages\botocore\endpoint.py:238, in Endpoint._get_response(self, request, operation_model, context)
#     232 def _get_response(self, request, operation_model, context):
#     233     # This will return a tuple of (success_response, exception)
#     234     # and success_response is itself a tuple of
#     235     # (http_response, parsed_dict).
#     236     # If an exception occurs then the success_response is None.
#     237     # If no exception occurs then exception is None.
# --> 238     success_response, exception = self._do_get_response(
#     239         request, operation_model, context
#     240     )
#     241     kwargs_to_emit = {
#     242         'response_dict': None,
#     243         'parsed_response': None,
#     244         'context': context,
#     245         'exception': exception,
#     246     }
#     247     if success_response is not None:
#
# File c:\Users\JaydenL\Documents\Uni\COMPX527\KiwiGuesser\.venv\Lib\site-packages\botocore\endpoint.py:278, in Endpoint._do_get_response(self, request, operation_model, context)
#     276     http_response = first_non_none_response(responses)
#     277     if http_response is None:
# --> 278         http_response = self._send(request)
#     279 except HTTPClientError as e:
#     280     return (None, e)
#
# File c:\Users\JaydenL\Documents\Uni\COMPX527\KiwiGuesser\.venv\Lib\site-packages\botocore\endpoint.py:382, in Endpoint._send(self, request)
#     381 def _send(self, request):
# --> 382     return self.http_session.send(request)
#
# File c:\Users\JaydenL\Documents\Uni\COMPX527\KiwiGuesser\.venv\Lib\site-packages\botocore\httpsession.py:464, in URLLib3Session.send(self, request)
#     461     conn.proxy_headers['host'] = host
#     463 request_target = self._get_request_target(request.url, proxy_url)
# --> 464 urllib_response = conn.urlopen(
#     465     method=request.method,
#     466     url=request_target,
#     467     body=request.body,
#     468     headers=request.headers,
#     469     retries=Retry(False),
#     470     assert_same_host=False,
#     471     preload_content=False,
#     472     decode_content=False,
#     473     chunked=self._chunked(request.headers),
#     474 )
#     476 http_response = botocore.awsrequest.AWSResponse(
#     477     request.url,
#     478     urllib_response.status,
#     479     urllib_response.headers,
#     480     urllib_response,
#     481 )
#     483 if not request.stream_output:
#     484     # Cause the raw stream to be exhausted immediately. We do it
#     485     # this way instead of using preload_content because
#     486     # preload_content will never buffer chunked responses
#
# File c:\Users\JaydenL\Documents\Uni\COMPX527\KiwiGuesser\.venv\Lib\site-packages\urllib3\connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     784 response_conn = conn if not release_conn else None
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#     803 clean_exit = True
#
# File c:\Users\JaydenL\Documents\Uni\COMPX527\KiwiGuesser\.venv\Lib\site-packages\urllib3\connectionpool.py:534, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     532 # Receive the response from the server
#     533 try:
# --> 534     response = conn.getresponse()
#     535 except (BaseSSLError, OSError) as e:
#     536     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File c:\Users\JaydenL\Documents\Uni\COMPX527\KiwiGuesser\.venv\Lib\site-packages\urllib3\connection.py:565, in HTTPConnection.getresponse(self)
#     562 _shutdown = getattr(self.sock, "shutdown", None)
#     564 # Get the response from http.client.HTTPConnection
# --> 565 httplib_response = super().getresponse()
#     567 try:
#     568     assert_header_parsing(httplib_response.msg)
#
# File C:\Program Files\Python311\Lib\http\client.py:1378, in HTTPConnection.getresponse(self)
#    1376 try:
#    1377     try:
# -> 1378         response.begin()
#    1379     except ConnectionError:
#    1380         self.close()
#
# File C:\Program Files\Python311\Lib\http\client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File C:\Program Files\Python311\Lib\http\client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File C:\Program Files\Python311\Lib\socket.py:706, in SocketIO.readinto(self, b)
#     704 while True:
#     705     try:
# --> 706         return self._sock.recv_into(b)
#     707     except timeout:
#     708         self._timeout_occurred = True
#
# File C:\Program Files\Python311\Lib\ssl.py:1278, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1274     if flags != 0:
#    1275         raise ValueError(
#    1276           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1277           self.__class__)
# -> 1278     return self.read(nbytes, buffer)
#    1279 else:
#    1280     return super().recv_into(buffer, nbytes, flags)
#
# File C:\Program Files\Python311\Lib\ssl.py:1134, in SSLSocket.read(self, len, buffer)
#    1132 try:
#    1133     if buffer is not None:
# -> 1134         return self._sslobj.read(len, buffer)
#    1135     else:
#    1136         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
print(files)

# %% [markdown]
# ### 2. Create Features and Viz (Optional)
#
# Read each file geo metadata

# %%
# We can derive the `bbox` from the filename
# s3://noaa-eri-pds/2020_Nashville_Tornado/20200307a_RGB/20200307aC0870130w361200n.tif
# -> 20200307aC0870130w361200n.tif
# -> 20200307aC "0870130w" "361200n" .tif
# -> 0870130w -> 87.025 (West)
# -> 361200n -> 36.2 (Top)
# We also know each files cover ~0.025x~0.025 degrees

import re
from geojson_pydantic.features import Feature
from geojson_pydantic.geometries import Polygon


def dms_to_degree(v: str) -> float:
    """convert degree minute second to decimal degrees.

    '0870130w' -> 87.025
    """
    deg = int(v[0:3])
    minutes = int(v[3:5])
    seconds = int(v[5:7])
    direction = v[-1].upper()
    return (float(deg) + float(minutes) / 60 + float(seconds) / (60 * 60)) * (
        -1 if direction in ["W", "S"] else 1
    )


def fname_to_feature(src_path: str) -> Feature:
    bname = os.path.basename(src_path)
    lon_dms = bname[10:18]
    lat_dms = bname[18:25]

    lon = dms_to_degree(lon_dms)
    lat = dms_to_degree("0" + lat_dms)

    return Feature(
        geometry=Polygon.from_bounds(lon, lat - 0.025, lon + 0.025, lat),
        properties={
            "path": src_path,
        },
    )


features = [fname_to_feature(f).dict(exclude_none=True) for f in files]

# OR We could use Rasterio/rio-tiler

# def worker(src_path: str) -> Feature:
#     try:
#         with COGReader(src_path) as cog:
#             wgs_bounds = cog.geographic_bounds
#     except:
#         return {}
#
#     return Feature(
#         geometry=Polygon.from_bounds(*wgs_bounds),
#         properties={
#             "path": src_path,
#         }
#     )
#
# with futures.ThreadPoolExecutor(max_workers=20) as executor:
#     features = [r.dict(exclude_none=True) for r in executor.map(worker, files) if r]

# %%
geojson = {"type": "FeatureCollection", "features": features}

bounds = featureBounds(geojson)

m = Map(
    tiles="OpenStreetMap",
    location=((bounds[1] + bounds[3]) / 2, (bounds[0] + bounds[2]) / 2),
    zoom_start=6,
)

geo_json = GeoJson(
    data=geojson,
    style_function=lambda x: {
        "opacity": 1,
        "dashArray": "1",
        "fillOpacity": 0,
        "weight": 1,
    },
)
geo_json.add_to(m)
m

# %% [markdown]
# ### 5. Create Mosaic

# %%
from rio_tiler.io import COGReader
from cogeo_mosaic.mosaic import MosaicJSON
from cogeo_mosaic.backends import MosaicBackend

with COGReader(files[0]) as cog:
    info = cog.info()
    print(info.minzoom)
    print(info.maxzoom)

# %%
# We are creating the mosaicJSON using the features we created earlier
# by default MosaicJSON.from_feature will look in feature.properties.path to get the path of the dataset
mosaicdata = MosaicJSON.from_features(
    features, minzoom=info.minzoom, maxzoom=info.maxzoom
)
with MosaicBackend("NOAA_Nashville_Tornado.json.gz", mosaic_def=mosaicdata) as mosaic:
    mosaic.write(overwrite=True)
    print(mosaic.info())

# %%
titiler_endpoint = (
    "https://titiler.xyz"  # Developmentseed Demo endpoint. Please be kind.
)

r = httpx.get(
    f"{titiler_endpoint}/mosaicjson/WebMercatorQuad/tilejson.json",
    params={
        # For this demo we are use the same mosaic but stored on the web
        "url": "https://gist.githubusercontent.com/vincentsarago/c6ace3ccd29a82a4a5531693bbcd61fc/raw/e0d0174a64a9acd2fb820f2c65b1830aab80f52b/NOAA_Nashville_Tornado.json"
    },
).json()
print(r)

m = Map(
    location=((bounds[1] + bounds[3]) / 2, (bounds[0] + bounds[2]) / 2), zoom_start=13
)

tiles = TileLayer(
    tiles=r["tiles"][0],
    min_zoom=r["minzoom"],
    max_zoom=r["maxzoom"],
    opacity=1,
    attr="NOAA",
)

geo_json = GeoJson(
    data=geojson,
    style_function=lambda x: {
        "opacity": 1,
        "dashArray": "1",
        "fillOpacity": 0,
        "weight": 1,
    },
)
tiles.add_to(m)
geo_json.add_to(m)
m
